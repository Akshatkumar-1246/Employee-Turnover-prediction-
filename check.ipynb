# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshatkumar-1246/Employee-Turnover-prediction-/blob/main/check.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello world')
# Out:
# hello world
